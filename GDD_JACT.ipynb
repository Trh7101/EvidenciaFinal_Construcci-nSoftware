# %% [markdown]
# # **Custom Racer**
#
# ## _Game Design Document_
#
# ---
#
# **Authors:**
# * Jacobo Soffer Levy | A01028653
# * Tonatiuh Reyes | A01025459
# * Salvador Federico Milanes Braniff | A01029956
#
# ## _Index_
#
# ---
#
# 1. [Index](#index)
# 2. [Game Design](#game-design)
#     1. [Summary](#summary)
#     2. [Gameplay](#gameplay)
#     3. [Mindset](#mindset)
# 3. [Technical](#technical)
#     1. [Screens](#screens)
#     2. [Controls](#controls)
#     3. [Mechanics](#mechanics)
# 4. [Level Design](#level-design)
#     1. [Themes](#themes)
#         1. Ambience
#         2. Objects
#             1. Ambient
#             2. Interactive
#         3. Challenges
#     2. [Game Flow](#game-flow)
# 5. [Development](#development)
#     1. [Abstract Classes](#abstract-classes--components)
#     2. [Derived Classes](#derived-classes--component-compositions)
# 6. [Graphics](#graphics)
#     1. [Style Attributes](#style-attributes)
#     2. [Graphics Needed](#graphics-needed)
# 7. [Sounds/Music](#soundsmusic)
#     1. [Style Attributes](#style-attributes-1)
#     2. [Sounds Needed](#sounds-needed)
#     3. [Music Needed](#music-needed)
# 8. [Schedule](#schedule)
#
# ## _Game Design_
#
# ---
#
# ### **Summary**
#
# A game that allows users to create custom racing-track courses by designing the track, environment, and item & obstacle layout; configuring gamplay rules and the overall look of the design based on switchable themes. Users can share or play levels of their own or created by other users.
#
# ### **Gameplay**
#
# #### Level Design
# Users should be able to design levels without any programming or game development experience via a simple drag and drop interface. Users can choose from an array of pieces and drag them onto a grid to design the main level. Examples of these include track segments, items, obstacles and scenery. Users can then configure additional settings through a menu such as the theme of their course (spring, summer, fall, winter), speed of the cars, time limit, etc. Finally, they can preview their course gameplay and publish it so other users can play their levels.
#
# #### Level Selection
# Users can browse levels created by other users and play them. Levels can optionally be organized in collections, as to create a complete game or group similar courses. Levels and collections can be searched and filtered using full text search.
#
# #### Level Gameplay
# In order to finish a game, users must complete a number of laps (set by the level creator). Additionally, levels may have a time limit. Two gamplay modes will be implemented (level creators can choose which one to use):
# * Players cannot move outside of the track and must go through all of the track in order for a lap to be counted.
# * Players can move freely but must pass through a series of checkpoints in order for the lap to be counted. This can increase difficulty by making it easy for the player to go off track and forcing them to go back.
#
# Obstacles placed in the track will make it harder for a player to complete a lap. Whenever a player hits an obstacle, an event may be triggered depending on the item type, for instance, on collision with an oil puddle they will be unable to move for a few seconds, falling on a lake will make them loose a life. When a player looses a ceirtain amount of lives (set by the level creator) the game will be over.
#
# Items placed in the track will make it easier for a player to complete a lap. Examples of items include speed ramps and extra lives.
#
# Users should be aware of the placement of obstacles and items in order to improve their time.
#
# The main challenge in the gameplay should be completing levels in as little time as possible. After each game, the time in which the level was completed will be posted to a leaderboard, this way users can compete against other users.
#
# ### **Mindset**
# The main goal of this game is to teach the fundamentals of game design and for anyone to be able to design their own levels and tracks. And in doing so, we expect that the players when making their tracks can feel both the struggle to make it functional and interesting, and also the acomplishment in being able to play it.
#
# In other hand when playing with other track designs, we expect that the players try as many levels while they try their best to acomplish record laps. That way they could feel the eager to compete to get the best times of as many levels as they play.
#
# ## _Technical_
#
# ---
#
# ### **Screens**
#
# 1. Title Screen
#     1. Options
# 2. Level Select
# 3. Game
#     1. Inventory
#     2. Assessment / Next Level
# 4. End Credits
#
# _(example)_
#
# ### **Controls**
#
# How will the player interact with the game? Will they be able to choose the controls? What kind of in-game events are they going to be able to trigger, and how? (e.g. pressing buttons, opening doors, etc.)
#
# The player will be able to interact with the game throught the mouse and keybord, even id the computer count with touchscreen that could be compatible too. The player won't be able to remap the preset controls, but we will attach to common race top-view games so it's easy to understand and play.
#
# ### **Mechanics**
#
# One mechanich we would highlight is the map creator, where you will be able to draw the ground, rivers, bridges, the circuit and more for decoration. This will be achived making a couple layers to save each level of priority of the objects, making the player able to draw things above others.
#
# ## _Level Design_
#
# ---
#
# As explainded before, users will be able to browse levels created by others and also create one themselves. Within the options to create a level the user is offered several options in different layers as:
#
#
# ### **Layers**
#
# 1. Ground
#     1. Grass
#         1. Winter, Summer, Spring, Autumm
#     2. Concrete
#     3. Bridges
#     4. Water
#
# 2. Obstacles
#     1. Fences
#     2. Oil spill
#         1. Big, Small
#     3. Traffic cones
#     4. Trees
#         1. Winter, Summer, Spring, Autumm
#
# _(example)_
#
# ### **Game Flow**
#
# 1. Player is menu
# 2. 2 main options, create level, browse level
#     1. Browse:
#         1. There is a menu where you can scroll down to show different levels, there is also an option to search for a specific (With name)
#         2. The players selects one and then can go into the race mode
#     2. Create Level:
#         1. The player can select from multiple options to customize and make his own level.
#         2. There is an option to play and try the level
#         3. Once done you can Final test the level and once you finish, the game will
# 3. To the right is a hill, player jumps to traverse it (&quot;jump&quot; taught)
# 4. Player encounters castle - door&#39;s shut and locked
# 5. There&#39;s a window within jump height, and a rock on the ground
# 6. Player picks up rock and throws at glass (&quot;throw&quot; taught)
# 7. … etc.
#
# _(example)_
#
# ## _Development_
#
# ---
#
# ### **Abstract Classes / Components**
#
# 1. BasePhysics
#     1. BasePlayer
#     2. BaseEnemy
#     3. BaseObject
# 2. BaseObstacle
# 3. BaseInteractable
#
# _(example)_
#
# ### **Derived Classes / Component Compositions**
#
# 1. BasePlayer
#     1. PlayerMain
#     2. PlayerUnlockable
# 2. BaseEnemy
#     1. EnemyWolf
#     2. EnemyGoblin
#     3. EnemyGuard (may drop key)
#     4. EnemyGiantRat
#     5. EnemyPrisoner
# 3. BaseObject
#     1. ObjectRock (pick-up-able, throwable)
#     2. ObjectChest (pick-up-able, throwable, spits gold coins with key)
#     3. ObjectGoldCoin (cha-ching!)
#     4. ObjectKey (pick-up-able, throwable)
# 4. BaseObstacle
#     1. ObstacleWindow (destroyed with rock)
#     2. ObstacleWall
#     3. ObstacleGate (watches to see if certain buttons are pressed)
# 5. BaseInteractable
#     1. InteractableButton
#
# _(example)_
#
# ## _Graphics_
#
# We desided using 2D graphics and use pixel art for it to be easier to handle and less time consuming.
#
# Also, we decided to go with that sytle to appeal to a nostalgic feeling of the first racing games.
#
# ### **Style Attributes**
#
# What kinds of colors will you be using? Do you have a limited palette to work with? A post-processed HSV map/image? Consistency is key for immersion.
#
# What kind of graphic style are you going for? Cartoony? Pixel-y? Cute? How, specifically? Solid, thick outlines with flat hues? Non-black outlines with limited tints/shades? Emphasize smooth curvatures over sharp angles? Describe a set of general rules depicting your style here.
#
# Well-designed feedback, both good (e.g. leveling up) and bad (e.g. being hit), are great for teaching the player how to play through trial and error, instead of scripting a lengthy tutorial. What kind of visual feedback are you going to use to let the player know they&#39;re interacting with something? That they \*can\* interact with something?
#
# ### **Graphics Needed**
#
# 1. Cars
#     1. Car??
# 2. Tiles
#     1. Dirt
#     2. Grass (it will have season variations such as winter, spring, etc.)
#     3. Water
#     4. Track
# 3. Ambient
#     1. Tall Grass
#     2. Flower
#     3. Tree (it will have season variations such as winter, spring, etc.)
# 4. Obstacles
#     1. Wheels
#     2. Traffic cones
#     3. oil spill
#
# _(example)_
#
#
# ## _Sounds/Music_
#
#
# ### **Style Attributes**
#
# As we are going with and pixel design, its better to use 8 bit music to reasemble more the old nostalgic race videogames. Also it is revelant to note that the music should feel dynamic.
#
#
# ### **Sounds Needed**
#
# 1. Effects
#     1. Motor (Idle, Running accelerating)
#     2. Wheel Burnout
#     3. Collision
# 2. Feedback
#     1. Race start countdown &quot;Twee&quot; (sounds each time the countdown progresses)
#     2. Completed Loop &quot;Ting!&quot; (For each loop)
#     3. Final Loop &quot;Finish!&quot;
#
# _(example)_
#
# ### **Music Needed**
#
# 1. Slow-paced, &quot;Menu&quot; track
# 2. Exciting and dynamic &quot;Race Mode&quot; track
# 4. Happy ending credits track
# 5. Rick Astley&#39;s hit #1 single &quot;Never Gonna Give You Up&quot;
#
# _(example)_
#
#
# ## _Schedule_
#
# ---
#
# _(define the main activities and the expected dates when they should be finished. This is only a reference, and can change as the project is developed)_
#
# 1. develop base classes
#     1. base entity
#         1. base player
#         2. base enemy
#         3. base block
#   2. base app state
#         1. game world
#         2. menu world
# 2. develop player and basic block classes
#     1. physics / collisions
# 3. find some smooth controls/physics
# 4. develop other derived classes
#     1. blocks
#         1. moving
#         2. falling
#         3. breaking
#         4. cloud
#     2. enemies
#         1. soldier
#         2. rat
#         3. etc.
# 5. design levels
#     1. introduce motion/jumping
#     2. introduce throwing
#     3. mind the pacing, let the player play between lessons
# 6. design sounds
# 7. design music
#
# _(example)_
